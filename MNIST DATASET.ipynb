# %% [markdown]
# <a href="https://colab.research.google.com/github/wardhakashif570/BOOTSTRAP-PRACTICE/blob/master/MNIST%20DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# **Loading the MNIST dataset**

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# **The network architecture**

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# **The compilation step**

# %%
network.compile(optimizer='rmsprop',
loss='categorical_crossentropy',
metrics=['accuracy'])

# %% [markdown]
# **Preparing the image data**

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %% [markdown]
# **Preparing the labels**

# %%
from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2547 - accuracy: 0.9269
# Epoch 2/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1035 - accuracy: 0.9698
# Epoch 3/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0677 - accuracy: 0.9789
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0495 - accuracy: 0.9852
# Epoch 5/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0366 - accuracy: 0.9891

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0665 - accuracy: 0.9808

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.9807999730110168

# %% [markdown]
# **Displaying the fourth digit**

# %%
print(train_images.dtype)
# Out:
# float32

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
print(train_images.ndim)
# Out:
# 3

# %%
print(train_images.shape)
# Out:
# (60000, 28, 28)

# %%
print(train_images.dtype)
# Out:
# uint8

# %%
digit = train_images[4]
import matplotlib.pyplot as plt
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()
